# %%
import torch
import dataclasses
import mediapy
from huggingface_hub import PyTorchModelHubMixin
from huggingface_hub import ModelCard
from gpudrive.networks.late_fusion import NeuralNet

from gpudrive.env.config import EnvConfig
from gpudrive.env.env_torch import GPUDriveTorchEnv
from gpudrive.visualize.utils import img_from_fig
from gpudrive.env.dataset import SceneDataLoader
from gpudrive.utils.config import load_config

# %% [markdown]
# ### Configs

# %%
# Configs model has been trained with
config = load_config("../../examples/experimental/config/reliable_agents_params")

print(config)

max_agents = config.max_controlled_agents
num_envs = 4
# num_envs = 7  # 不要超过数据集文件中的json个数
device = "cpu" # cpu just because we're in a notebook
# Out:
# {'max_controlled_agents': 64, 'ego_state': True, 'road_map_obs': True, 'partner_obs': True, 'norm_obs': True, 'remove_non_vehicles': True, 'lidar_obs': False, 'reward_type': 'weighted_combination', 'collision_weight': -0.75, 'off_road_weight': -0.75, 'goal_achieved_weight': 1.0, 'dynamics_model': 'classic', 'collision_behavior': 'ignore', 'dist_to_goal_threshold': 2.0, 'polyline_reduction_threshold': 0.1, 'sampling_seed': 42, 'obs_radius': 50.0, 'action_space_steer_disc': 13, 'action_space_accel_disc': 7, 'init_mode': 'all_non_trivial', 'vbd_in_obs': False}

# %% [markdown]
# ### Load pre-trained agent via Hugging Face hub

# %%
sim_agent = NeuralNet.from_pretrained("daphne-cornelisse/policy_S10_000_02_27")

# %%
# Agent has an action dimension of 91: 13 steering wheel angle discretizations x 9 acceleration discretizations
sim_agent.action_dim
# Out:
# 91

# %%
# Size of flattened observation vector
sim_agent.obs_dim
# Out:
# 2984

# %%
# Some other info
card = ModelCard.load("daphne-cornelisse/policy_S10_000_02_27")
card.data.tags
# Out:
# ['ffn', 'model_hub_mixin', 'pytorch_model_hub_mixin']

# %%
# Model architecture
#agent

# %%
# Weights 
#agent.state_dict()

# %% [markdown]
# ### Make environment

# %%
# Create data loader
train_loader = SceneDataLoader(
    root='../../data/processed/examples',
    # root = '../../data/processed/testing',
    batch_size=num_envs,
    dataset_size=100,
    sample_with_replacement=False,
)

# Set params
env_config = dataclasses.replace(
    EnvConfig(),
    ego_state=config.ego_state,
    road_map_obs=config.road_map_obs,
    partner_obs=config.partner_obs,
    reward_type=config.reward_type,
    norm_obs=config.norm_obs,
    dynamics_model=config.dynamics_model,
    collision_behavior=config.collision_behavior,
    dist_to_goal_threshold=config.dist_to_goal_threshold,
    polyline_reduction_threshold=config.polyline_reduction_threshold,
    remove_non_vehicles=config.remove_non_vehicles,
    lidar_obs=config.lidar_obs,
    disable_classic_obs=config.lidar_obs,
    obs_radius=config.obs_radius,
    steer_actions = torch.round(
        torch.linspace(-torch.pi, torch.pi, config.action_space_steer_disc), decimals=3  
    ),
    accel_actions = torch.round(
        torch.linspace(-4.0, 4.0, config.action_space_accel_disc), decimals=3
    ),
)

# Make env
env = GPUDriveTorchEnv(
    config=env_config,
    data_loader=train_loader,
    max_cont_agents=config.max_controlled_agents,
    device=device,
)

# %%
env.data_batch  # 感觉是顺着数据集的顺序走的，所以需要shuffle
# Out:
# ['../../data/processed/examples/tfrecord-00000-of-01000_325.json',
#  '../../data/processed/examples/tfrecord-00000-of-01000_4.json',
#  '../../data/processed/examples/tfrecord-00000-of-01000_402.json',
#  '../../data/processed/examples/tfrecord-00002-of-01000_407.json']

# %% [markdown]
# ### Use the agent

# %%
next_obs = env.reset()

control_mask = env.cont_agent_mask

next_obs.shape
# Out:
# torch.Size([4, 64, 2984])

# %%
action, logprob, entropy, value = sim_agent(
    next_obs[control_mask], deterministic=False
)

# %%
action.shape, logprob.shape, entropy.shape, value.shape
# Out:
# (torch.Size([62]), torch.Size([62]), torch.Size([62]), torch.Size([62, 1]))

# %% [markdown]
# ### Rollout

# %%
next_obs = env.reset()

control_mask = env.cont_agent_mask

print(control_mask)
print("next_obs.shape:", next_obs.shape)
print("next_obs[control_mask].shape:", next_obs[control_mask].shape)
print("env.max_agent_count:", env.max_agent_count)
print("max_agents:", max_agents)

frames = {f"env_{i}": [] for i in range(num_envs)}

for time_step in range(env.episode_len):
    print(f"\rStep: {time_step}", end="", flush=True)

    # Predict actions
    action, _, _, _ = sim_agent(
        next_obs[control_mask], deterministic=False
    )

    # action_template = torch.zeros(
    #     (num_envs, max_agents), dtype=torch.int64, device=device
    # )
    # 修复：使用正确的形状 [num_envs, max_agent_count]
    action_template = torch.zeros(
        (num_envs, env.max_agent_count), dtype=torch.int64, device=device
    )

    # print("action_template:", action_template)
    # print("action:", action)
    action_template[control_mask] = action.to(device)

    # Step
    env.step_dynamics(action_template)

    # Render    
    sim_states = env.vis.plot_simulator_state(
        env_indices=list(range(num_envs)),
        time_steps=[time_step]*num_envs,
        zoom_radius=70,
    )
    
    for i in range(num_envs):
        frames[f"env_{i}"].append(img_from_fig(sim_states[i])) 

    next_obs = env.get_obs()
    reward = env.get_rewards()
    done = env.get_dones()
    info = env.get_infos()
    
    if done.all():
        break

env.close()
# Out:
# tensor([[ True,  True,  True,  True, False, False, False, False, False, False,
#          False, False,  True, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False, False,
#          False, False, False, False],
#         [ True,  True,  True, False,  True, False,  True, False, False, False,
#           True, False, False, False, False, False, False, False,  True, False,
#          False, False, False,  True, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False, False,
#          False, False, False, False],
#         [ True,  True,  True,  True,  True,  True,  True,  True,  True,  True,
#           True,  True,  True,  True,  True,  True,  True,  True,  True,  True,
#           True,  True,  True,  True,  True,  True,  True,  True,  True,  True,
#           True,  True,  True,  True,  True,  True,  True,  True,  True,  True,
#           True,  True,  True,  True,  True, False,  True, False, False, False,
#          False, False, False, False, False, False, False, False, False, False,
#          False, False, False, False],
#         [ True,  True,  True, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False, False,
#          False, False, False, False]])
# next_obs.shape: torch.Size([4, 64, 2984])
# next_obs[control_mask].shape: torch.Size([62, 2984])
# env.max_agent_count: 64
# max_agents: 64
# Step: 69

# %%
mediapy.show_videos(frames, fps=15, width=500, height=500, columns=2, codec='gif')
# Out:
# <table class="show_videos" style="border-spacing:0px;"><tr><td style="padding:1px;"><div style="display:flex; align-items:left;">
#       <div style="display:flex; flex-direction:column; align-items:center;">
#       <div>env_0</div><div><img width="500" height="500" style="image-rendering:auto; object-fit:cover;" src="data:image/gif;base64,..."/></div></div></div></td><td style="padding:1px;"><div style="display:flex; align-items:left;">
#       <div style="display:flex; flex-direction:column; align-items:center;">
#       <div>env_1</div><div><img width="500" height="500" style="image-rendering:auto; object-fit:cover;" src="data:image/gif;base64,..."/></div></div></div></td></tr></table><table class="show_videos" style="border-spacing:0px;"><tr><td style="padding:1px;"><div style="display:flex; align-items:left;">
#       <div style="display:flex; flex-direction:column; align-items:center;">
#       <div>env_2</div><div><img width="500" height="500" style="image-rendering:auto; object-fit:cover;" src="data:image/gif;base64,..."/></div></div></div></td><td style="padding:1px;"><div style="display:flex; align-items:left;">
#       <div style="display:flex; flex-direction:column; align-items:center;">
#       <div>env_3</div><div><img width="500" height="500" style="image-rendering:auto; object-fit:cover;" src="data:image/gif;base64,..."/></div></div></div></td></tr></table>
